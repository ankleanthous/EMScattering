# %% [markdown]
# # Random orientation

# %% [markdown]
# ## Scattering in the far-field

# %% [markdown]
# Definitions from: [Scattering, absorption, and emission of light by small particles, Mishchenko et al., 2002.](https://pubs.giss.nasa.gov/books/2002_Mishchenko_mi06300n/2002_Mishchenko_etal_1.pdf)
#
# ![setup.png](attachment:setup.png)
#
# We consider an arbitrary point $O$ close to the geometrical centre of the scattering object as the common origin of all position vectors as in Figure \ref{fig:setup}.
# We denote the direction of propagation of an incident plane electromagnetic wave by $\hat{\mathbf{n}}^{inc}$, which depends on ($\theta^{inc}, \phi^{inc}$), where $\theta^{inc} \in [0,\pi]$ is the polar (zenith) angle and $\phi^{inc} \in [0,2\pi)$ is the azimuth angle.
# The corresponding unit vectors are $\hat{\mathbf{\theta}}^{inc}$ and $\hat{\mathbf{\phi}}^{inc}$ such that $\hat{\mathbf{n}}^{inc} = \hat{\mathbf{\theta}}^{inc} \times \hat{\mathbf{\phi}}^{inc} $ and defined as
# \begin{align}
#     \hat{\mathbf{n}}^{inc} = \begin{bmatrix}
#     \sin \theta^{inc} \cos \phi^{inc} \\
#     \sin \theta^{inc} \sin \phi^{inc} \\
#     \cos \theta^{inc}
#     \end{bmatrix}, \
#     %
#     \hat{\mathbf{\theta}}^{inc} = \begin{bmatrix}
#     \cos \theta^{inc} \cos \phi^{inc} \\
#     \cos \theta^{inc} \sin \phi^{inc}\\
#     -\sin \theta^{inc}
#     \end{bmatrix}, \
#     %
#     \hat{\mathbf{\phi}}^{inc} = \begin{bmatrix}
#     -\sin \phi^{inc}\\
#     \cos \phi^{inc}\\
#     0
#     \end{bmatrix}.
# \end{align}
#
# If the medium of propagation is non absorbing, the component of the electric field vector along the direction of propagation $\hat{\mathbf{n}}^{inc}$ is zero and the incident field can then be decomposed into components lying in the $\hat{\mathbf{\theta}}^{inc}$ and $\hat{\mathbf{\phi}}^{inc}$ directions as follows
# \begin{align}
#     \mathbf{E}^{inc} = (E_\theta^{inc} \hat{\mathbf{\theta}}^{inc} + E_\phi^{inc} \hat{\mathbf{\phi}}^{inc}) \exp (ik_e \hat{\mathbf{n}}^{inc} \cdot \mathbf{r}),
# \end{align}
# where $E_\theta^{inc} \hat{\mathbf{\theta}}^{inc}$ and $E_\phi^{inc} \hat{\mathbf{\phi}}^{inc}$ define the polarisation vectors.
# In the same manner, one can create a coordinate system $\hat{\mathbf{n}}^{sca}, \hat{\mathbf{\theta}}^{sca}, \hat{\mathbf{\phi}}^{sca}$ to describe the scattered wave.
#
# The scattered far-field, $\mathbf{E}^{s,f}$, decays inversely with distance $r$ from the scattering object
# \begin{align}
#     \mathbf{E}^{s,f} (\hat{\mathbf{n}}^{sca}) \sim \frac{e^{ik_e r}}{r} \mathbf{F}(\hat{\mathbf{n}}^{sca}), \quad r \rightarrow \infty.
# \end{align}
# The vector $\mathbf{F}$ is independent of $r$ and describes the angular distribution of the scattered field radiation in the far-field zone. It can be computed via the asymptotic form of Stratton Chu representation formulae
# \begin{align}
#     \mathbf{F}(\mathbf{x}) = - \sum_m^M \mathcal{H}^{e,f}_m \left(\gamma^+_{D,m} \mathbf{E}^s_m\right) - \sum_m^M \mathcal{E}^{e,f}_m \left( \gamma^+ _{N,m} \mathbf{E}^s_m \right),
# \end{align}
# where $\mathcal{H}^{e,f}$ and $\mathcal{E}^{e,f}$ are the far-field versions of the magnetic and electric potential operators given as
# \begin{align}
#     \mathcal{H}^{e,f}\mathbf{v}(\mathbf{x}) :=& \frac{ik_e}{4\pi} \int_\Gamma \exp \left(  \frac{-i k_e \mathbf{x} \cdot \mathbf{y}}{|\mathbf{x}|}\right) \left( \frac{\mathbf{x}}{|\mathbf{x}|} \times \mathbf{v} (\mathbf{y})\right) d\Gamma (\mathbf{y}), \\
#     %
#     \mathcal{E}^{e,f}\mathbf{v}(\mathbf{x}) :=& \frac{ik_e}{4\pi} \int_\Gamma \exp \left( \frac{-ik_e \mathbf{x} \cdot \mathbf{y}}{|\mathbf{x}|} \right) \mathbf{v}(\mathbf{y}) d\Gamma(\mathbf{y}) - \frac{ik_e}{4\pi} \int_\Gamma \exp \left( \frac{-ik_e \mathbf{x}\cdot \mathbf{y}}{|\mathbf{x}|}  \right) \mathbf{v}(\mathbf{y}) \cdot \frac{\mathbf{x}}{|\mathbf{x}|} d\Gamma (\mathbf{y}).
# \end{align}

# %% [markdown]
# ### Amplitude scattering matrix p.37-38
#
# The amplitude scattering matrix $\mathbf{S}$ describes the transformation of the $\theta$ and $\phi$ components of the incident plane wave into the $\theta$ and $\phi$ components of the scattered spherical wave in the far-field
# \begin{align}
#     \begin{bmatrix}
#     E^{s,f}_\theta \\
#     E^{s,f}_\phi
#     \end{bmatrix} = \frac{e^{ik_er}}{r} \mathbf{S}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}) \begin{bmatrix}
#     E^{inc}_\theta  \\
#     E^{inc}_\phi
#     \end{bmatrix}, \quad r \rightarrow \infty.
# \end{align}
# The amplitude scattering matrix depends on the directions of incident and scattering waves as well as the size, morphology, composition, and orientation of the scattering object with respect to the coordinate system. It also depends on the choice of origin of the coordinate system inside the scattering object.
# The elements of the amplitude matrix are expressed as follows
# \begin{align}
#     S_{11} &= \hat{\mathbf{\theta}}^{sca} \cdot \mathbf{F}^{s,f}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{\theta}}^{inc}), \qquad
#     S_{12} = \hat{\mathbf{\theta}}^{sca} \cdot \mathbf{F}^{s,f}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{\phi}}^{inc}), \\
#     S_{21} &= \hat{\mathbf{\phi}}^{sca} \cdot \mathbf{F}^{s,f}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{\theta}}^{inc}), \qquad
#     S_{22} = \hat{\mathbf{\phi}}^{sca} \cdot \mathbf{F}^{s,f}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{\phi}}^{inc}).
# \end{align}
# By $\mathbf{F}^{s,f}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{\theta}}^{inc})$ we mean the scattered far-field created by the $\hat{\mathbf{\theta}}^{inc}$ component of the incident plane wave, i.e. $E^{inc}_\theta \hat{\mathbf{\theta}}^{inc} \exp ( ik_e \hat{\mathbf{n}}^{inc} \cdot \mathbf{r})$ and evaluated in the scattering direction $\hat{\mathbf{n}}^{sca}$. Analogous definitions can be made for $\mathbf{F}^{s,f}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{\phi}}^{inc})$.

# %% [markdown]
# ### Phase matrix p.49-54
# The elements of the phase matrix, $\mathbf{Z}$, in terms of the amplitude matrix are
# \begin{align}
#     Z_{11} &= \frac{1}{2} \left( |S_{11}|^2 + |S_{12}|^2 + |S_{21}|^2 + |S_{22}|^2 \right), \\
#     Z_{12} &= \frac{1}{2} \left( |S_{11}|^2 - |S_{12}|^2 + |S_{21}|^2 - |S_{22}|^2 \right), \\
#     Z_{13} &= - \Re\left( S_{11} S^*_{12} + S_{22} S^*_{21}\right), \\
#     Z_{14} &= - \Im\left( S_{11} S^*_{12} - S_{22} S^*_{21}\right), \\
#     Z_{21} &= \frac{1}{2} \left( |S_{11}|^2 + |S_{12}|^2 - |S_{21}|^2 - |S_{22}|^2 \right), \\
#     Z_{22} &= \frac{1}{2} \left( |S_{11}|^2 - |S_{12}|^2 - |S_{21}|^2 + |S_{22}|^2 \right), \\
#     Z_{23} &= - \Re\left( S_{11} S^*_{12} - S_{22} S^*_{21}\right), \\
#     Z_{24} &= - \Im\left( S_{11} S^*_{12} + S_{22} S^*_{21}\right), \\
#     Z_{31} &= - \Re\left( S_{11} S^*_{21} + S_{22} S^*_{12}\right), \\
#     Z_{32} &= - \Re\left( S_{11} S^*_{21} - S_{22} S^*_{12}\right), \\
#     Z_{33} &= \Re\left( S_{11} S^*_{22} + S_{12} S^*_{21}\right), \\
#     Z_{34} &= \Im\left( S_{11} S^*_{22} + S_{21} S^*_{12}\right), \\
#     Z_{41} &= - \Im\left( S_{21} S^*_{11} + S_{22} S^*_{12}\right), \\
#     Z_{42} &= - \Im\left( S_{21} S^*_{11} - S_{22} S^*_{12}\right), \\
#     Z_{43} &= \Im\left( S_{22} S^*_{11} - S_{12} S^*_{21}\right), \\
#     Z_{44} &= \Re\left( S_{22} S^*_{11} - S_{12} S^*_{21}\right),
# \end{align}
# where $\Re$ and $\Im$ denote the real and imaginary parts respectively.

# %% [markdown]
# ### SSPs: Extinction, scattering, and absorption cross sections, p.56-60
# The extinction, scattering and back-scattering cross sections can be computed as follows \begin{align}
#     C_{ext} & = \frac{1}{2} \left(C_{ext,\theta} + C_{ext,\phi}\right), \\
#     C_{sca} & = \frac{1}{2} \left(C_{sca,\theta} + C_{sca,\phi}\right), \\
#     C_{bsca} & = 4 \pi Z_{11}(\theta^{sca} = \pi),
# \end{align}
# where the individual $\hat{\mathbf{\theta}}$ and $\hat{\mathbf{\phi}}$ components can be computed as follows
# \begin{align}
#     C_{ext, x} &= \frac{4\pi}{k_e |E^{inc}_x \hat{\mathbf{x}}^{inc}|^2} \Im\left(\mathbf{F}^{s,f}(\hat{\mathbf{n}}^{sca}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{x}}^{inc}) \cdot \left(E^{inc}_x \hat{\mathbf{x}}^{inc}\right)^*\right), \\
#     C_{sca, x} &= \frac{1}{|E^{inc}_x \hat{\mathbf{x}}^{inc}|^2} \int_{4\pi} |\mathbf{F}^{s,f}(\hat{\mathbf{r}}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{x}}^{inc})|^2 d \hat{\mathbf{r}}.
# \end{align}
# The scattering albedo is defined as the ratio of the scattering and extinction cross sections
# \begin{align}
#     \varpi_0 = \frac{C_{sca}}{C_{ext}} \leq 1.
# \end{align}
# The asymmetry parameter $\langle \cos \Theta \rangle$ is defined as the average cosine of the scattering angle $\Theta = \arccos (\hat{\mathbf{r}} \cdot \hat{\mathbf{n}}^{inc})$, i.e. the angle between the incidence and the scattering directions
# \begin{align}
#     g = \langle \cos \Theta \rangle = \frac{1}{2} \left( g_\theta + g_\phi \right),
# \end{align}
# where the individual components can be computed by
# \begin{align}
#     g_x = \frac{1}{C_{sca,x}} \int_{4\pi} |\mathbf{F}^{s,f}(\hat{\mathbf{r}}, \hat{\mathbf{n}}^{inc}, \hat{\mathbf{x}}^{inc})|^2 \hat{\mathbf{r}} \cdot \hat{\mathbf{n}}^{inc} d \hat{\mathbf{r}}.
# \end{align}
# The asymmetry parameter is positive if the particle scatters more light toward the forward direction ($\Theta = 0$), is negative if more light is scattered towards the back-scattering direction ($\Theta=\pi$), and vanishes if the scattering is symmetric with respect to the plane perpendicular to the incidence direction, with $g \in [-1,+1]$.
#
# For the evaluation of any integrals over the sphere (for example for the evaluation of $C_{sca}$ and $g$) we use Lebedev quadrature \cite{lebedev1975values, lebedev1976quadratures, lebedev1977spherical,lebedev1992quadrature, lebedev1995quadrature, lebedev1999quadrature}.
# This is to take advantage of the discrete grid points $(\theta_i, \phi_i)$ being available as a pair and hence reducing the number of loops to one.
# In this case, a surface integral of a function over the unit sphere
# \begin{align}
#     I[f] = \int_{4\pi} f(\hat{\mathbf{r}}) d\hat{\mathbf{r}} = \int_0^\pi sin(\theta) d\theta \int_0^{2\pi} f(\theta, \phi) d\phi,
# \end{align}
# would be approximated by the Lebedev scheme as
# \begin{align}
#     \tilde{I}[f] = 4\pi \sum_{i=1}^N \omega_i f(\theta_i, \phi_i),
# \end{align}
# where $\omega_i$ are the weights corresponding to grid points $(\theta_i, \phi_i)$. Compared to, for example, products of one-dimensional Gaussian quadratures approximating the integral by
# \begin{align}
#     \tilde{I}[f] = \sum_{i=1}^N \sum_{j=1}^M \omega_i v_j f(\theta_i, \phi_j),
# \end{align}
# for appropriate weight functions $\omega_i$ and $v_j$, Lebedev quadrature is faster to evaluate.
# Construction of the Lebedev grid points and weights can be tedius but we take advantage of
# pre-computed numerical values for the nodes and weights [available here](https://bitbucket.org/CasperBeentjes/quadratures-on-unit-sphere/src/master/). We note that for the evaluation of $C_{sca}$ and $g$ we use Lebedev quadrature of order 59 resulting in 1202 grid points.
#
# We note that there are alternative ways of computing $C_{sca}$ and $g$ through the phase matrix element $Z_{11}$ and the relative difference between the two definitions is usually used to check the accuracy of the implementation
# \begin{align}
#     C_{sca} &= \int_{0}^{2\pi} \int_{0}^{\pi} Z_{11}(\theta) \sin \theta d\theta d\phi, \\
#     g &= \int_{0}^{2\pi} \int_{0}^{\pi} Z_{11}(\theta) \sin \theta \cos \theta d\theta d\phi.
# \end{align}

# %% [markdown]
# ## Random Orientation
#
# Averaging some quantity $f$ over random particle orientations is represented by \cite{mishchenko2017concept}
# \begin{align}
#     \langle f \rangle = \frac{1}{8\pi^2} \int_0^{2\pi}\int_0^\pi  \int_0^{2\pi} f(\alpha, \beta, \gamma) \sin \beta \ d \alpha \ d \beta \ d \gamma.
# \end{align}
# The traditional approach to evaluate the SSPs and phase matrix of randomly oriented particles is to fix the direction of the incident wave, and then rotate the scatterer using three Euler angles $\alpha, \beta, \gamma$ (as described for example in \cite{mishchenko2000calculation}). The rotation matrix representing the three rotations is given by
# \begin{align}
#     R_{\alpha\beta\gamma} &= R_z(\gamma) R_y(\beta) R_z(\alpha)
#     = \begin{bmatrix}
#     \cos \gamma & \sin \gamma & 0 \\
#     -\sin \gamma & \cos \gamma & 0 \\
#     0 & 0 & 1
#     \end{bmatrix}
#     \begin{bmatrix}
#     \cos \beta & 0 & -\sin \beta \\
#     0 & 1 & 0 \\
#     \sin \beta & 0 & \cos \beta \\
#     \end{bmatrix}
#     \begin{bmatrix}
#     \cos \alpha & \sin \alpha & 0 \\
#     -\sin \alpha & \cos \alpha & 0 \\
#     0 & 0 & 1
#     \end{bmatrix}.
# \end{align}
# The SSPs and phase matrix are then evaluated for some scattering angles $(\theta^{sca}, \phi^{sca})$. Once many orientations have been considered one can use \eqref{eqn:orientation_average} to compute the orientationally averaged quantity.
#
# This traditional approach would be too expensive to follow using BEM. The rotation of the scatterer would imply that a new operator $\mathbf{A}$ and preconditioner $\mathbf{P}$ would need to be assembled for each orientation considered, requiring large amounts of memory and assembly times. Fixing the direction of the incident wave and rotating the scatterer by $R_{\alpha\beta\gamma}$ is equivalent to fixing the orientation of the scatterer and instead rotating the direction of the incident wave by $R^{-1}_{\alpha\beta\gamma}$ and this methodology has also been considered in \cite{brath2020microwave}. This enables us to assemble the operator matrix and preconditioner once and re-use for all incident wave solutions. We note that for each incident wave, two GMRES solves need to be performed; one for each polarisation vector as described in \eqref{eqn:coordinate_vectors}, but different GMRES solves can be distributed over different CPUs to reduce the total computational time.
#
# Assuming a fixed incident wave direction with fixed $\theta^{inc}=\phi^{inc}=0$ in \eqref{eqn:coordinate_vectors}, gives
# \begin{align}
#     \hat{\mathbf{n}}^{inc} = \begin{bmatrix}
#     0 \\ 0 \\ 1
#     \end{bmatrix}, \quad
#     \hat{\mathbf{\theta}}^{inc} = \begin{bmatrix}
#     1 \\ 0 \\ 0
#     \end{bmatrix}, \quad
#     \hat{\mathbf{\phi}}^{inc} = \begin{bmatrix}
#     0 \\ 1 \\ 0
#     \end{bmatrix}.
# \end{align}
# These can then be rotated by $R^{-1}_{\alpha,\beta,\gamma}$ given by
# \begin{align}
#     R^{-1}_{\alpha,\beta,\gamma} &= R_z^{-1}(\alpha) R_y^{-1}(\beta) R^{-1}_z(\gamma),
# \end{align}
# giving the rotated incident directions and polarisation vectors
# \begin{align}
#     \hat{\mathbf{n}}^{inc} &= \begin{bmatrix}
#     \cos \alpha \sin \beta \\
#     \sin \alpha \sin \beta \\
#     \cos \beta
#     \end{bmatrix}, \quad
#     \hat{\mathbf{\theta}}^{inc} = \begin{bmatrix}
#     \cos\alpha \cos \beta \cos \gamma - \sin \alpha \sin \gamma \\
#      \sin \alpha \cos \beta \cos \gamma + \cos \alpha \sin \gamma \\
#      -\sin \beta \cos \gamma
#     \end{bmatrix}, \quad
#     \hat{\mathbf{\phi}}^{inc} = \begin{bmatrix}
#     -\cos \alpha \cos \beta \sin \gamma -\sin\alpha\cos\gamma \\
#     -\sin \alpha \cos \beta \sin \gamma + \cos \alpha \cos \gamma \\
#     \sin \beta \sin \gamma
#     \end{bmatrix},
# \end{align}
# that can be varied for different $\alpha, \beta, \gamma$. Comparing with the definitions of \eqref{eqn:coordinate_vectors}, we can see that both $\hat{\mathbf{n}}^{inc}$ are equivalent with $\alpha = \phi^{inc}$ and $\beta = \theta^{inc}$, i.e. the direction of the incident wave does not depend on the angle $\gamma$ and can be defined using a pair of grid points $(\theta^{inc}, \phi^{inc})$. It is only the polarisation vectors $\hat{\mathbf{\theta}}^{inc}$ and $\hat{\mathbf{\phi}}^{inc}$ that need to be altered by an additional angle.
#
# This allows us to make use of Lebedev quadrature to obtain the grid points $(\theta_i^{inc}, \phi_i^{inc})$ that define the direction of the incident wave, reducing the two integrals over $\theta^{inc}$ and $\phi^{inc}$ (or $\alpha$ and $\beta$ as defined in \eqref{eqn:orientation_average}) to just one. The third integral over $\gamma$ can then be evaluated by a simple Gaussian integration.

# %% [markdown]
# ## Code

# %% [markdown]
# We first import all necessary packages.

# %%
import bempp.api
import numpy as np

import time
from iterative_solvers import gmres, get_h
from operators import PMCHWT_operator, PMCHWT_preconditioner, mass_matrix_BC_SNC
from multiprocessing import Pool, cpu_count

bempp.api.global_parameters.assembly.potential_operator_assembly_type = 'dense'

# %% [markdown]
# Next we set up the parameters for the operator and preconditioner when a bi-parametric implementation is used. For more details on the bi-parametric implementation of the PMCHWT formulation see the paper by [Kleanthous *et al.*](https://arxiv.org/pdf/2008.04772.pdf) with its corresponding [repository](https://github.com/ankleanthous/Accelerated_Calderon). To be able to use the cutoff parameter, you need Bempp version 3.3.5 (Docker image) or 3.3.4 (source code)

# %%
from bempp.core.common.global_parameters import global_parameters # Interface to define global_parameters for operators

quad_P= [1,1,1,1]
quad_A= [4,3,2,6]

hmat_tol_A = 0.1
hmat_tol_P = 0.001
near_field_cutoff_P = 0

# Parameters for operator A
parameters_A = global_parameters()
parameters_A.assembly.boundary_operator_assembly_type='hmat'
parameters_A.hmat.eps = hmat_tol_A
parameters_A.quadrature.double_singular = quad_A[3]
parameters_A.quadrature.far.double_order = quad_A[2]
parameters_A.quadrature.medium.double_order = quad_A[1]
parameters_A.quadrature.near.double_order = quad_A[0]

# Parameters for preconditioner P
parameters_P = global_parameters()
parameters_P.assembly.boundary_operator_assembly_type='hmat'
parameters_P.hmat.eps = hmat_tol_P
parameters_P.quadrature.double_singular = quad_P[3]
parameters_P.quadrature.far.double_order = quad_P[2]
parameters_P.quadrature.medium.double_order = quad_P[1]
parameters_P.quadrature.near.double_order = quad_P[0]
parameters_P.hmat.cutoff = near_field_cutoff_P

# %% [markdown]
# The following provide test cases to compare with [T-matrix solutions](https://www.sciencedirect.com/science/article/pii/S0022407300001278?casa_token=bpCckl7RhFEAAAAA:Q7hXu1vH0Z7128jqlSnSMVxeiRRbxzAZkaYTz813rOUltesOB_B-ZbNok2skaKp57LMlSZoDzA). Available size parameters are 0.05, 0.1 and 1.

# %%
frequency = 50E9
wavelength = 3E8/frequency
print(wavelength)
k_ext = 2*np.pi/wavelength
print(k_ext)
h = 2*np.pi/(10*k_ext)
print(h)
grid = bempp.api.import_grid('test_cases/random/hex_1.msh')

grids = [grid]
r = [1.7746+0.00064j]
number_of_scatterers = len(grids)

data = np.loadtxt('test_cases/random/Mishchenko_hexcol_1.txt', dtype = float)
Z11_Tmatrix = data[:,1]#*1E-12
Z22_Tmatrix = data[:,2]#*1E-12
Z33_Tmatrix = data[:,3]#*1E-12
Z44_Tmatrix = data[:,4]#*1E-12
Z12_Tmatrix = data[:,5]#*1E-12
Z34_Tmatrix = data[:,6]#*1E-12
Tmatrix_coords = data[:,0]
Tmatrix_coords = np.radians(Tmatrix_coords)

data = np.loadtxt('test_cases/random/SSPs_hexcol_1.txt')
Cext_Tmatrix = data[0] * 1E-12 #converting to meters^2
Csca_Tmatrix = data[1] * 1E-12
g_Tmatrix = data[2]
w_Tmatrix = data[3]
Cbsca_Tmatrix = Z11_Tmatrix[-1] * Csca_Tmatrix
# Out:
# 0.006
# 1047.1975511965977
# 0.0006000000000000001

# %%
Nelements = np.sum([np.shape(grid.leaf_view.elements)[1] for grid in grids])
print('Elements: ',Nelements)

print(get_h(grid))
[_,h_max,_] = get_h(grid)

n_ind = r * number_of_scatterers
k_int = [k_ext * i for i in n_ind]

mu_ext = 1.0
mu_int = [1.0] * number_of_scatterers
# Out:
# Elements:  180
# [0.00029670135861496093, 0.00056331297113478354, 0.00045102871509297487]

# %%
def get_memory(number_of_scatterers, operator):
    mem = 0
    for i in range(2*number_of_scatterers):
        for j in range(2*number_of_scatterers):
            op = operator[i][j]
            mem += op.memory
    return mem

# %% [markdown]
# The following sets up the necessary spaces, the operator *PMCHWT_op* and the preconditioner *PMCHWT_pre*. The default choice of preconditioner is $\mathbf{D}^i$. For more details see the paper by [Kleanthous *et al.* (2020)](https://arxiv.org/pdf/2008.04772.pdf).

# %%
# Set spaces
rwg_space = [bempp.api.function_space(grid, 'RWG', 0) for grid in grids]
snc_space = [bempp.api.function_space(grid, 'SNC', 0) for grid in grids]
bc_space = [bempp.api.function_space(grid, 'BC', 0) for grid in grids]
rbc_space = [bempp.api.function_space(grid, 'RBC', 0) for grid in grids]

b_rwg_space = [bempp.api.function_space(grid, "B-RWG", 0) for grid in grids]
b_snc_space = [bempp.api.function_space(grid, "B-SNC", 0) for grid in grids]

N = sum([space.global_dof_count for space in rwg_space])
print (N ,'NDOF')

[PMCHWT_op, filter_operators] = PMCHWT_operator(grids, k_ext, k_int, mu_ext, mu_int, parameters = parameters_A)

PMCHWT_pre = PMCHWT_preconditioner(grids, k_ext, k_int, mu_ext, mu_int, parameters = parameters_P)
mass_matrix = mass_matrix_BC_SNC(grids)

t0 = time.time()
pre_sf = PMCHWT_pre.strong_form()
op_wf = PMCHWT_op.weak_form()
cald_op_sf = pre_sf * mass_matrix * op_wf
ta_cald_op_sf = time.time() - t0
print('assembly time: {0:.3f} mins'.format(ta_cald_op_sf/60))
print('memory op: {0:.3f} GB'.format(get_memory(number_of_scatterers, op_wf)/(2*1024**2)))
# Out:
# 270 NDOF
# assembly time: 0.040 mins
# memory op: 0.004 GB

# %% [markdown]
# The accurate calculation of the SSPs depends on the number of incident waves considered.
# n_averaging denotes the order of the Lebedev scheme that is used to simulate random orientation. Numerical experiments have shown that this needs to be altered with the size parameter of the problem considered as follows
#
# - $X \lessapprox 1$: 14 incident waves (Lebedev scheme of order 3),
#
# - $1\lessapprox X \lessapprox 3$: 50 incident waves (Lebedev scheme of order 11),
#
# - $3 \lessapprox X \lessapprox 5$: 110 incident waves (Lebedev scheme of order 17),
#
# - $5 \lessapprox X \lessapprox 8$: 194 incident waves (Lebedev scheme of order 23),
#
# - $8 \lessapprox X \lessapprox 10$: 230 incident waves (Lebedev scheme of order 25),
#
# - $X \gtrapprox 10$: 302 incident waves (Lebedev scheme of order 29).
#
# We note that these are approximate so might be altered for different geometries. Geometries of size parameter $X>10$ are likely to need more incident waves. For a list of available Lebedev schemes see files in *far_field/PointDistFiles/lebedev/*

# %%
n_averaging = 5 
if n_averaging <10:
    coord = np.loadtxt('far_field/PointDistFiles/lebedev/lebedev_00{0}.txt'.format(n_averaging))
else:
    coord = np.loadtxt('far_field/PointDistFiles/lebedev/lebedev_0{0}.txt'.format(n_averaging))
w_averaging = coord[:,2] #weights
n_waves = np.shape(w_averaging)[0]
print('Number of waves: {0}'.format(n_waves))
phi_averaging = np.radians(coord[:,0]) #phi
theta_averaging = np.radians(coord[:,1])#theta
# Out:
# Number of waves: 14

# %%
number_of_angles = 1801

n_leb = 101
coord = np.loadtxt('far_field/PointDistFiles/lebedev/lebedev_{0}.txt'.format(n_leb))
w_leb = coord[:,2] #weights
phi_leb = np.radians(coord[:,0]) #phi
theta_leb = np.radians(coord[:,1])#theta

# %% [markdown]
# For the accurate calculation of the phase matrix, one also needs to vary the polarisation vectors. These are implemented through Gaussian integration. From experiments we found that
#
# - aggregates $X\lessapprox 1$: 10 rotations,
# - aggregates $1\lessapprox X \lessapprox 24$: 15 rotations,
# - aggregates $X\geq 24$: 20 rotations.
#
# The rotation of the polarisation vectors does not affect the accuracy of the SSPs so if the phase matrix is not of interest, N_gauss can be set to 1.

# %%
N_gauss = 10
[angles_gauss, weights_gamma] = np.polynomial.legendre.leggauss(N_gauss)
weights_gamma = weights_gamma/2
print(angles_gauss)
angles_gauss = (2*np.pi)*angles_gauss/2 + (2*np.pi)/2
print(angles_gauss)
print(weights_gamma)
print(np.sum(weights_gamma))
# Out:
# [-0.97390653 -0.86506337 -0.67940957 -0.43339539 -0.14887434  0.14887434
#   0.43339539  0.67940957  0.86506337  0.97390653]
# [ 0.08197506  0.42391594  1.00716455  1.78004087  2.67389012  3.60929518
#   4.50314444  5.27602076  5.85926937  6.20121025]
# [ 0.03333567  0.07472567  0.10954318  0.13463336  0.14776211  0.14776211
#   0.13463336  0.10954318  0.07472567  0.03333567]
# 1.0

# %% [markdown]
# The next cell sets the maximum number of iterations, the restart parameter and the tolerance of GMRES.

# %%
restart = 400
maxiter = 400
tol=1E-5

# %% [markdown]
# The next cell sets up the incident waves, discretises the RHS and solves the two matrix systems by GMRES (one for each polarisation vector). Then the SSPs and phase matrix are evaluated.

# %%
def incident_wave_func(counter_gauss, counter_lebedev):

    print(counter_gauss, counter_lebedev)
    x = angles_gauss[counter_gauss]
    weights = w_averaging[counter_lebedev]
    theta_inc = theta_averaging[counter_lebedev]
    phi_inc = phi_averaging[counter_lebedev]
    

    incident_direction = np.array([np.sin(theta_inc) * np.cos(phi_inc), 
                                   np.sin(theta_inc) * np.sin(phi_inc), 
                                    np.cos(theta_inc)])
    vector_theta_inc = np.array([np.cos(theta_inc) * np.cos(phi_inc) * np.cos(x) - np.sin(phi_inc)*np.sin(x), 
                                 np.cos(theta_inc) * np.sin(phi_inc) * np.cos(x) + np.cos(phi_inc) * np.sin(x), 
                                 -np.sin(theta_inc) * np.cos(x)])
    vector_phi_inc = np.array([-np.sin(phi_inc) * np.cos(x) - np.cos(phi_inc) * np.cos(theta_inc) * np.sin(x), 
                               np.cos(phi_inc) * np.cos(x) - np.sin(phi_inc) * np.cos(theta_inc) * np.sin(x), 
                              np.sin(theta_inc) * np.sin(x)])

    def plane_wave_phi(point):
        return vector_phi_inc * np.exp(1j * k_ext * np.dot(point, incident_direction))

    def plane_wave_theta(point):
        return vector_theta_inc * np.exp(1j * k_ext * np.dot(point, incident_direction))

    def dirichlet_trace_phi_inc(point, n, domain_index, result):
        result[:] =  np.cross(plane_wave_phi(point), n)

    def dirichlet_trace_theta_inc(point, n, domain_index, result):
        result[:] =  np.cross(plane_wave_theta(point), n)

    def plane_wave_curl_phi(point):
        return np.cross(incident_direction, vector_phi_inc) * 1j * k_ext * np.exp(1j * k_ext * np.dot(point, incident_direction))

    def plane_wave_curl_theta(point):
        return np.cross(incident_direction, vector_theta_inc) * 1j * k_ext * np.exp(1j * k_ext * np.dot(point, incident_direction))

    def neumann_trace_phi_inc(point, n, domain_index, result):
        result[:] =  1./ (1j * k_ext) * np.cross(plane_wave_curl_phi(point), n)

    def neumann_trace_theta_inc(point, n, domain_index, result):
        result[:] =  1./ (1j * k_ext) * np.cross(plane_wave_curl_theta(point), n)
    ##############################################################################
    # sovling for incident field
    ##############################################################################
    incident_dirichlet_phi = []
    incident_neumann_phi = []
    incident_dirichlet_theta = []
    incident_neumann_theta = []

    for i in range(number_of_scatterers):
        incident_dirichlet_phi.append(bempp.api.GridFunction(rwg_space[i], fun = dirichlet_trace_phi_inc))
        incident_neumann_phi.append((k_ext/mu_ext) * bempp.api.GridFunction(rwg_space[i], fun=neumann_trace_phi_inc))

        incident_dirichlet_theta.append(bempp.api.GridFunction(rwg_space[i], fun = dirichlet_trace_theta_inc))
        incident_neumann_theta.append((k_ext/mu_ext) * bempp.api.GridFunction(rwg_space[i], fun=neumann_trace_theta_inc))

    # Set RHS
    rhs_phi = number_of_scatterers * [None]
    rhs_theta = number_of_scatterers * [None]

    for i in range(number_of_scatterers):
        filter_op_wf = filter_operators[i].weak_form()
        rhs_phi[i] = filter_op_wf * (incident_dirichlet_phi[i].coefficients.tolist()+ incident_neumann_phi[i].coefficients.tolist())
        rhs_theta[i] = filter_op_wf * (incident_dirichlet_theta[i].coefficients.tolist() + incident_neumann_theta[i].coefficients.tolist())

    rhs_phi = [y for x in rhs_phi for y in x]
    rhs_theta = [y for x in rhs_theta for y in x]

    rhs_phi = pre_sf * mass_matrix * rhs_phi
    rhs_theta = pre_sf * mass_matrix * rhs_theta

    print('GMRES solves')
    t0 = time.time()
    x_phi, info_phi, iters_phi = gmres(cald_op_sf, rhs_phi, tol=tol, restart = restart, maxiter = maxiter, return_residuals = True)
    t_solve_phi = time.time() - t0
    if len(iters_phi) == maxiter:
        raise ValueError('Maximum number of iterations reached before convergence. Choose a larger maxiter above')

    t0 = time.time()
    x_theta, info_theta, iters_theta = gmres(cald_op_sf, rhs_theta, tol=tol, restart = restart, maxiter = maxiter, return_residuals = True)
    t_solve_theta = time.time() - t0
    print('{0},{1}:  solver time phi: {2} mins \n iters phi: {3}'.format(counter_gauss, counter_lebedev,t_solve_phi/60, len(iters_phi)))
    print('{0},{1}:  solver time theta: {2} mins \n iters theta: {3}'.format(counter_gauss, counter_lebedev,t_solve_theta/60, len(iters_theta)))
    if len(iters_theta) == maxiter:
        raise ValueError('Maximum number of iterations reached before convergence. Choose a larger maxiter above')

    scattered_dirichlet_exterior_phi = number_of_scatterers * [None]
    scattered_neumann_exterior_phi = number_of_scatterers * [None]

    scattered_dirichlet_exterior_theta = number_of_scatterers * [None]
    scattered_neumann_exterior_theta = number_of_scatterers * [None]

    sum_dofs = 0
    for i in range(number_of_scatterers):
        scattered_dirichlet_exterior_phi[i] = x_phi[2*sum_dofs: 2*sum_dofs + rwg_space[i].global_dof_count]
        scattered_neumann_exterior_phi[i] =  (mu_ext / k_ext) *  x_phi[2*sum_dofs + rwg_space[i].global_dof_count : 
                                                                   2*sum_dofs + 2*rwg_space[i].global_dof_count]

        scattered_dirichlet_exterior_theta[i] = x_theta[2*sum_dofs: 2*sum_dofs + rwg_space[i].global_dof_count]
        scattered_neumann_exterior_theta[i] =  (mu_ext / k_ext) *  x_theta[2*sum_dofs + rwg_space[i].global_dof_count : 
                                                                   2*sum_dofs + 2*rwg_space[i].global_dof_count]

        sum_dofs += rwg_space[i].global_dof_count

    ###################################################################################
    ## Computing Cext
    ###################################################################################
    far_field_phi = np.zeros((3, 1), dtype='complex128')
    far_field_theta = np.zeros((3, 1), dtype = 'complex128')

    incident_direction = np.array([[np.sin(theta_inc) * np.cos(phi_inc),
                                   np.sin(theta_inc) * np.sin(phi_inc),
                                   np.cos(theta_inc)]])

    for i in range(number_of_scatterers):

        electric_far = bempp.api.operators.far_field.maxwell.electric_field(rwg_space[i], incident_direction.T, k_ext)
        magnetic_far = bempp.api.operators.far_field.maxwell.magnetic_field(rwg_space[i], incident_direction.T, k_ext)    

        sc_N_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_phi[i])
        sc_D_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_phi[i])

        sc_N_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_theta[i])
        sc_D_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_theta[i])

        far_field_phi += -electric_far * sc_N_phi - magnetic_far * sc_D_phi
        far_field_theta += -electric_far * sc_N_theta - magnetic_far * sc_D_theta


    
    Cext_phi = 4*np.pi/(k_ext * np.linalg.norm(vector_phi_inc)**2) * np.imag(np.dot(far_field_phi[:,0], np.conjugate(vector_phi_inc)))
    Cext_theta = 4*np.pi/(k_ext * np.linalg.norm(vector_theta_inc)**2) * np.imag(np.dot(far_field_theta[:,0],np.conjugate(vector_theta_inc)))
    Cext = 0.5* (Cext_phi + Cext_theta)
    
    ###################################################################################
    ## Computing Csca
    ###################################################################################
    coord_leb_Csca = np.vstack([np.sin(theta_leb)*np.cos(phi_leb), 
                                np.sin(theta_leb)*np.sin(phi_leb), 
                                np.cos(theta_leb)])
    ff_quad_phi = np.zeros(np.shape(coord_leb_Csca), dtype='complex128')
    ff_quad_theta = np.zeros(np.shape(coord_leb_Csca), dtype = 'complex128')
    bempp.api.global_parameters.assembly.potential_operator_assembly_type = 'dense'

    R_theta = np.array([[np.cos(theta_inc), 0 ,np.sin(theta_inc)], [0,1,0], [-np.sin(theta_inc), 0, np.cos(theta_inc)]])
    R_phi = np.array([[np.cos(phi_inc), -np.sin(phi_inc), 0], [np.sin(phi_inc), np.cos(phi_inc), 0], [0,0,1]])
    R_x = np.array([[np.cos(x), -np.sin(x), 0], [np.sin(x), np.cos(x), 0], [0,0,1]])

    beta_matrix = np.dot(R_phi, np.dot(R_theta, R_x))
    coord_leb_Csca = np.dot(beta_matrix, coord_leb_Csca)
    
    for i in range(number_of_scatterers):

        electric_far = bempp.api.operators.far_field.maxwell.electric_field(rwg_space[i], coord_leb_Csca, k_ext)
        magnetic_far = bempp.api.operators.far_field.maxwell.magnetic_field(rwg_space[i], coord_leb_Csca, k_ext)    

        sc_N_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_phi[i])
        sc_D_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_phi[i])

        sc_N_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_theta[i])
        sc_D_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_theta[i])

        ff_quad_phi += -electric_far * sc_N_phi - magnetic_far * sc_D_phi
        ff_quad_theta += -electric_far * sc_N_theta - magnetic_far * sc_D_theta

    ff_quad_phi_mag = np.linalg.norm(ff_quad_phi, axis = 0)**2
    ff_quad_theta_mag = np.linalg.norm(ff_quad_theta, axis = 0)**2

    Int_phi = 4*np.pi * np.dot(ff_quad_phi_mag,w_leb)
    Int_theta = 4*np.pi * np.dot(ff_quad_theta_mag,w_leb)# the 4*np.pi factor comes from the quadrature rule

    Csca_phi = 1/np.linalg.norm(vector_phi_inc)**2 * Int_phi
    Csca_theta = 1/np.linalg.norm(vector_theta_inc)**2 * Int_theta

    Csca = 0.5 * (Csca_phi + Csca_theta)
    w = Csca/Cext
    ############################################################################################
    ## Computing g
    ############################################################################################
    coord_leb_g = np.vstack([np.sin(theta_leb)*np.cos(phi_leb), 
                             np.sin(theta_leb)*np.sin(phi_leb), 
                             np.cos(theta_leb)])
    ff_quad_phi = np.zeros(np.shape(coord_leb_g), dtype='complex128')
    ff_quad_theta = np.zeros(np.shape(coord_leb_g), dtype = 'complex128')
      

    coord_leb_g = np.dot(beta_matrix, coord_leb_g)

    for i in range(number_of_scatterers):
        electric_far = bempp.api.operators.far_field.maxwell.electric_field(rwg_space[i], coord_leb_g, k_ext)
        magnetic_far = bempp.api.operators.far_field.maxwell.magnetic_field(rwg_space[i], coord_leb_g, k_ext)

        sc_N_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_phi[i])
        sc_D_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_phi[i])

        sc_N_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_theta[i])
        sc_D_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_theta[i])

        ff_quad_phi += -electric_far * sc_N_phi - magnetic_far * sc_D_phi
        ff_quad_theta += -electric_far * sc_N_theta - magnetic_far * sc_D_theta

    ff_quad_phi_mag = np.linalg.norm(ff_quad_phi, axis = 0)**2
    ff_quad_theta_mag = np.linalg.norm(ff_quad_theta, axis = 0)**2

   
    Int_g_phi = 4*np.pi * np.dot(np.dot(incident_direction,coord_leb_g)*ff_quad_phi_mag, w_leb)
    Int_g_theta = 4 * np.pi * np.dot(np.dot(incident_direction,coord_leb_g)*ff_quad_theta_mag, w_leb)

    g = 0.5/Csca * (Int_g_phi[0] + Int_g_theta[0])

    ##################################################################
    ## Computing phase matrix
    ##################################################################
    far_field_phi = np.zeros((3, number_of_angles), dtype='complex128')
    far_field_theta = np.zeros((3, number_of_angles), dtype = 'complex128')

    angles_theta = np.linspace(0 , np.pi , number_of_angles)
    angles_phi = 0. #+ phi_inc

    scattering_direction = np.array([np.sin(angles_theta) * np.cos(angles_phi),
                                     np.sin(angles_theta) * np.sin(angles_phi),
                                     np.cos(angles_theta)])
    scattering_direction = np.dot(beta_matrix, scattering_direction)
    
    for i in range(number_of_scatterers):
        electric_far = bempp.api.operators.far_field.maxwell.electric_field(rwg_space[i],scattering_direction, k_ext)
        magnetic_far = bempp.api.operators.far_field.maxwell.magnetic_field(rwg_space[i],scattering_direction, k_ext)

        sc_N_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_phi[i])
        sc_D_phi = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_phi[i])

        sc_N_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_neumann_exterior_theta[i])
        sc_D_theta = bempp.api.GridFunction(rwg_space[i], coefficients = scattered_dirichlet_exterior_theta[i])

        far_field_phi += -electric_far * sc_N_phi - magnetic_far * sc_D_phi
        far_field_theta += -electric_far * sc_N_theta - magnetic_far * sc_D_theta
    
    
    vector_theta_sca = np.array([np.cos(angles_theta)*np.cos(angles_phi),
                                np.cos(angles_theta)*np.sin(angles_phi),
                                -np.sin(angles_theta)])
    vector_phi_sca = np.array([-np.sin(angles_phi)*np.ones(number_of_angles),
                               np.cos(angles_phi)*np.ones(number_of_angles),
                               np.zeros(number_of_angles)])
    

    vector_theta_sca = np.dot(beta_matrix, vector_theta_sca)
    vector_phi_sca = np.dot(beta_matrix, vector_phi_sca)
    
    a11 = []
    a12 = []
    a21 = []
    a22 = []

    for i in range(number_of_angles):
        a11.append(np.dot(vector_theta_sca[:,i], far_field_theta[:,i]))
        a12.append(np.dot(vector_theta_sca[:,i], far_field_phi[:,i]))
        a21.append(np.dot(vector_phi_sca[:,i], far_field_theta[:,i]))
        a22.append(np.dot(vector_phi_sca[:,i], far_field_phi[:,i]))
    
     
    S11 = np.array(a11)
    S12 = np.array(a12)
    S21 = np.array(a21)
    S22 = np.array(a22)

   
    Z11 = 0.5 * (abs(S11)**2 + abs(S12)**2 + abs(S21)**2 + abs(S22)**2)
    Z12 = 0.5*(abs(S11)**2-abs(S22)**2+abs(S21)**2-abs(S12)**2)
    Z13 = -np.real(S11*np.conjugate(S12)+S22*np.conjugate(S21))
    Z14 = -np.imag(S11*np.conjugate(S12)-S22*np.conjugate(S21))
    Z21 = 0.5*(abs(S11)**2-abs(S22)**2-abs(S21)**2+abs(S12)**2)
    Z22 = 0.5*(abs(S11)**2+abs(S22)**2-abs(S21)**2-abs(S12)**2)
    Z23 = -np.real(S11*np.conjugate(S12)-S22*np.conjugate(S21))
    Z24 = -np.imag(S11*np.conjugate(S12)+S22*np.conjugate(S21))
    Z31 = -np.real(S11*np.conjugate(S21)+S22*np.conjugate(S12))
    Z32 = -np.real(S11*np.conjugate(S21)-S22*np.conjugate(S12))
    Z33 = np.real(np.conjugate(S11)*S22+S12*np.conjugate(S21))
    Z34 = np.imag(S11*np.conjugate(S22)+S21*np.conjugate(S12))
    Z41 = -np.imag(np.conjugate(S11)*S21+np.conjugate(S12)*S22)
    Z42 = -np.imag(np.conjugate(S11)*S21-np.conjugate(S12)*S22)
    Z43 = np.imag(S22*np.conjugate(S11)-S12*np.conjugate(S21))
    Z44 = np.real(np.conjugate(S11)*S22-S12*np.conjugate(S21))
    
    Cbsca = Z11[-1] * 4 * np.pi

    return (counter_gauss,counter_lebedev, weights, theta_inc, phi_inc, len(iters_phi), len(iters_theta), t_solve_phi/60, t_solve_theta/60, 
            Cext, Csca, w, g, Cbsca, Z11, Z12, Z13, Z14, Z21, Z22, Z23, Z24, Z31, Z32, Z33, Z34, Z41, Z42, Z43, Z44)

# %% [markdown]
# The following distributes the multiple incident waves to the different CPUs available. For large problems, the number of process will have to be reduced.

# %%
starttime = time.time()
if __name__ == '__main__':
    p = Pool(processes = cpu_count())
    a = p.starmap(incident_wave_func, [(counter_gauss,counter_lebedev) for counter_gauss in range(N_gauss) for counter_lebedev in range(np.shape(w_averaging)[0])])
    p.close()
    p.join()
endtime = time.time()
print('Total time: {0} mins'.format((endtime - starttime)/60))
print('-------------------------------------------------------------------')
# Out:
# 0 2
# 0 1
# 0 7
# 0 3
# 0 4
# 0 5
# 0 9
# 0 6
# 0 10
# 1 0
# 0 13
# 1 3
# 0 12
# 1 2
# 0 11
# 1 6
# 1 10
# 1 5
# 1 8
# 0 0
# 1 9
# 1 12
# 1 4
# 1 13
# 2 4
# 2 0
# 2 2
# 1 7
# 2 10
# 2 7
# 2 6
# 0 8
# 2 8
# 1 11
# 2 1
# 2 9
# 2 3
# 2 5
# 2 11
# 1 1
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 1,10:  solver time phi: 0.06699004173278808 mins
#  iters phi: 24
# 1,10:  solver time theta: 0.10495076974232992 mins
#  iters theta: 24
# 1,12:  solver time phi: 0.07465353409449259 mins
#  iters phi: 24
# 1,12:  solver time theta: 0.10493146578470866 mins
#  iters theta: 24
# 2,8:  solver time phi: 0.08684759537378947 mins
#  iters phi: 23
# 2,8:  solver time theta: 0.0947511633237203 mins
#  iters theta: 24
# 1,1:  solver time phi: 0.08737542231877644 mins
#  iters phi: 24
# 0,3:  solver time phi: 0.0875953714052836 mins
#  iters phi: 241,1:  solver time theta: 0.0952240506807963 mins
#  iters theta: 23
#
# 0,3:  solver time theta: 0.09636786778767904 mins
#  iters theta: 23
# 0,4:  solver time phi: 0.0733946442604065 mins
#  iters phi: 24
# 0,4:  solver time theta: 0.1111921230951945 mins
#  iters theta: 24
# 1,8:  solver time phi: 0.0841053287188212 mins
#  iters phi: 24
# 1,8:  solver time theta: 0.10251318216323853 mins
#  iters theta: 24
# 0,0:  solver time phi: 0.0999768098195394 mins
#  iters phi: 23
# 0,0:  solver time theta: 0.09495741923650106 mins
#  iters theta: 23
# 2,0:  solver time phi: 0.09110376040140787 mins
#  iters phi: 23
# 2,6:  solver time phi: 0.08667766253153483 mins
#  iters phi: 242,0:  solver time theta: 0.09981631835301717 mins
#  iters theta: 232,2:  solver time phi: 0.0876786470413208 mins
#  iters phi: 24
# 2,6:  solver time theta: 0.10494625568389893 mins
#  iters theta: 25
#
#
# 2,2:  solver time theta: 0.10395802656809489 mins
#  iters theta: 24
# 1,7:  solver time phi: 0.09384332100550334 mins
#  iters phi: 25
# 1,7:  solver time theta: 0.101597793896993 mins
#  iters theta: 242,1:  solver time phi: 0.08042637507120769 mins
#  iters phi: 23
#
# 2,1:  solver time theta: 0.1192652980486552 mins
#  iters theta: 23
# 2,4:  solver time phi: 0.08891670306523641 mins
#  iters phi: 24
# 2,4:  solver time theta: 0.10517337322235107 mins
#  iters theta: 242,9:  solver time phi: 0.08917137781778971 mins
#  iters phi: 24
#
# 2,9:  solver time theta: 0.11014457543690999 mins
#  iters theta: 24
# 2,11:  solver time phi: 0.0923186699549357 mins
#  iters phi: 241,9:  solver time phi: 0.1016522725423177 mins
#  iters phi: 24
# 1,2:  solver time phi: 0.08767412106196086 mins
#  iters phi: 24
# 1,9:  solver time theta: 0.10138469934463501 mins
#  iters theta: 232,11:  solver time theta: 0.11319183905919393 mins
#  iters theta: 24
#
#
# 1,2:  solver time theta: 0.11073224544525147 mins
#  iters theta: 24
# 1,6:  solver time phi: 0.10332416693369548 mins
#  iters phi: 24
# 1,6:  solver time theta: 0.10404232343037924 mins
#  iters theta: 23
# 2,3:  solver time phi: 0.09717598358790079 mins
#  iters phi: 23
# 2,3:  solver time theta: 0.10783893267313639 mins
#  iters theta: 24
# 2,7:  solver time phi: 0.10888891220092774 mins
#  iters phi: 24
# 2,7:  solver time theta: 0.10166999101638793 mins
#  iters theta: 241,4:  solver time phi: 0.09513802925745646 mins
#  iters phi: 24
#
# 0,1:  solver time phi: 0.10961352189381918 mins
#  iters phi: 23
# 1,4:  solver time theta: 0.12007972399393717 mins
#  iters theta: 24
# 0,1:  solver time theta: 0.10148760875066122 mins
#  iters theta: 22
# 2,5:  solver time phi: 0.10318290789922079 mins
#  iters phi: 24
# 2,5:  solver time theta: 0.10990362167358399 mins
#  iters theta: 24
# 1,3:  solver time phi: 0.10009201367696126 mins
#  iters phi: 24
# 1,3:  solver time theta: 0.11684584617614746 mins
#  iters theta: 230,2:  solver time phi: 0.1148102084795634 mins
#  iters phi: 24
#
# 0,2:  solver time theta: 0.10920788049697876 mins
#  iters theta: 231,5:  solver time phi: 0.11062480211257934 mins
#  iters phi: 24
#
# 1,5:  solver time theta: 0.10748433669408163 mins
#  iters theta: 24
# 0,9:  solver time phi: 0.10535995960235596 mins
#  iters phi: 24
# 0,9:  solver time theta: 0.11768816312154134 mins
#  iters theta: 24
# 1,11:  solver time phi: 0.11197944482167561 mins
#  iters phi: 24
# 1,11:  solver time theta: 0.1107153614362081 mins
#  iters theta: 240,7:  solver time phi: 0.1239864428838094 mins
#  iters phi: 252,10:  solver time phi: 0.12265741427739461 mins
#  iters phi: 24
#
#
# 0,7:  solver time theta: 0.10021816492080689 mins
#  iters theta: 232,10:  solver time theta: 0.10359388987223307 mins
#  iters theta: 24
#
# 0,10:  solver time phi: 0.09778632322947184 mins
#  iters phi: 24
# 0,10:  solver time theta: 0.12794466813405356 mins
#  iters theta: 240,5:  solver time phi: 0.11863412459691365 mins
#  iters phi: 24
#
# 0,5:  solver time theta: 0.10659863551457723 mins
#  iters theta: 23
# 0,13:  solver time phi: 0.11419802109400432 mins
#  iters phi: 25
# 0,13:  solver time theta: 0.12001022497812906 mins
#  iters theta: 24
# 0,8:  solver time phi: 0.11706258058547973 mins
#  iters phi: 24
# 0,8:  solver time theta: 0.11717503070831299 mins
#  iters theta: 240,11:  solver time phi: 0.11105817159016927 mins
#  iters phi: 24
#
# 0,11:  solver time theta: 0.12353917360305786 mins
#  iters theta: 240,12:  solver time phi: 0.1248091220855713 mins
#  iters phi: 24
#
# 0,12:  solver time theta: 0.11041125059127807 mins
#  iters theta: 24
# 1,0:  solver time phi: 0.12087151606877646 mins
#  iters phi: 24
# 1,0:  solver time theta: 0.12246733109156291 mins
#  iters theta: 23
# 0,6:  solver time phi: 0.11679209470748901 mins
#  iters phi: 24
# 0,6:  solver time theta: 0.12881709337234498 mins
#  iters theta: 24
# 1,13:  solver time phi: 0.11652680238087972 mins
#  iters phi: 24
# 1,13:  solver time theta: 0.13050955931345623 mins
#  iters theta: 24
# 2 12
# 2 13
# GMRES solves
# 3 0
# GMRES solves
# 3 1
# GMRES solves
# 3 2
# 3 3
# GMRES solves
# 3 4
# 3 5
# 3 6
# 3 7
# 3 8
# 3 9
# GMRES solves
# 3 10
# GMRES solves
# 3 11
# GMRES solves
# 3 12
# GMRES solves
# 3 13
# GMRES solves
# 4 0
# GMRES solves
# GMRES solves
# 4 1
# GMRES solves
# GMRES solves
# 4 2
# 4 3
# 4 4
# GMRES solves
# GMRES solves
# 4 5
# 4 6
# 4 7
# 4 8
# GMRES solves
# GMRES solves
# GMRES solves
# 4 9
# 4 10
# GMRES solves
# 4 11
# 4 12
# GMRES solves
# 4 13
# 5 0
# GMRES solves
# 5 1
# GMRES solves
# 5 2
# GMRES solves
# 5 3
# 5 4
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 5 5
# 5 6
# GMRES solves
# 5 7
# GMRES solves
# 5 8
# GMRES solves
# 5 9
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 2,12:  solver time phi: 0.1139267086982727 mins
#  iters phi: 24
# 2,12:  solver time theta: 0.09824019273122152 mins
#  iters theta: 24
# 3,0:  solver time phi: 0.10147073666254679 mins
#  iters phi: 23
# 3,0:  solver time theta: 0.0940914233525594 mins
#  iters theta: 23
# 2,13:  solver time phi: 0.12430224418640137 mins
#  iters phi: 24
# 2,13:  solver time theta: 0.11016889015833536 mins
#  iters theta: 24
# 3,1:  solver time phi: 0.12148855924606324 mins
#  iters phi: 23
# 3,1:  solver time theta: 0.09409382740656534 mins
#  iters theta: 23
# 3,5:  solver time phi: 0.08662693897883098 mins
#  iters phi: 24
# 3,5:  solver time theta: 0.10787235498428345 mins
#  iters theta: 24
# 3,3:  solver time phi: 0.09902936617533366 mins
#  iters phi: 23
# 3,2:  solver time phi: 0.10615123112996419 mins
#  iters phi: 233,3:  solver time theta: 0.09774337609608968 mins
#  iters theta: 24
#
# 3,2:  solver time theta: 0.10184278488159179 mins
#  iters theta: 24
# 3,9:  solver time phi: 0.0933659553527832 mins
#  iters phi: 24
# 3,9:  solver time theta: 0.10068488915761312 mins
#  iters theta: 24
# 3,6:  solver time phi: 0.11184308926264445 mins
#  iters phi: 24
# 3,6:  solver time theta: 0.08930124839146932 mins
#  iters theta: 24
# 4,0:  solver time phi: 0.09132044315338135 mins
#  iters phi: 23
# 4,0:  solver time theta: 0.09492963155110677 mins
#  iters theta: 23
# 3,4:  solver time phi: 0.11392083565394083 mins
#  iters phi: 243,10:  solver time phi: 0.1214424212773641 mins
#  iters phi: 24
#
# 3,4:  solver time theta: 0.11109947363535563 mins
#  iters theta: 243,10:  solver time theta: 0.08815561930338542 mins
#  iters theta: 24
#
# 4,6:  solver time phi: 0.10163598855336507 mins
#  iters phi: 25
# 4,6:  solver time theta: 0.07507434686024984 mins
#  iters theta: 23
# 4,1:  solver time phi: 0.10290637811024984 mins
#  iters phi: 23
# 4,1:  solver time theta: 0.09164002339045206 mins
#  iters theta: 23
# 3,7:  solver time phi: 0.10686269203821817 mins
#  iters phi: 23
# 3,7:  solver time theta: 0.12124714056650797 mins
#  iters theta: 25
# 3,13:  solver time phi: 0.10621795654296876 mins
#  iters phi: 243,12:  solver time phi: 0.10272015730539957 mins
#  iters phi: 24
#
# 3,12:  solver time theta: 0.10385081370671591 mins
#  iters theta: 243,13:  solver time theta: 0.10019948085149129 mins
#  iters theta: 25
#
# 4,3:  solver time phi: 0.08950762351353964 mins
#  iters phi: 24
# 4,3:  solver time theta: 0.10652556419372558 mins
#  iters theta: 23
# 4,2:  solver time phi: 0.10460703372955323 mins
#  iters phi: 24
# 4,2:  solver time theta: 0.10618526140848795 mins
#  iters theta: 23
# 4,8:  solver time phi: 0.09937851031621298 mins
#  iters phi: 24
# 4,8:  solver time theta: 0.09490755796432496 mins
#  iters theta: 23
# 3,8:  solver time phi: 0.11841412782669067 mins
#  iters phi: 24
# 3,8:  solver time theta: 0.13127350807189941 mins
#  iters theta: 244,13:  solver time phi: 0.07412363688151041 mins
#  iters phi: 24
#
# 4,13:  solver time theta: 0.12018776734670003 mins
#  iters theta: 24
# 5,1:  solver time phi: 0.09054787556330363 mins
#  iters phi: 24
# 5,1:  solver time theta: 0.11110605398813883 mins
#  iters theta: 23
# 3,11:  solver time phi: 0.1180702527364095 mins
#  iters phi: 24
# 3,11:  solver time theta: 0.1284252127011617 mins
#  iters theta: 24
# 4,4:  solver time phi: 0.10904647509256998 mins
#  iters phi: 24
# 4,7:  solver time phi: 0.09059117635091146 mins
#  iters phi: 244,4:  solver time theta: 0.12540512482325236 mins
#  iters theta: 24
#
# 4,7:  solver time theta: 0.12580931186676025 mins
#  iters theta: 23
# 4,5:  solver time phi: 0.09582710266113281 mins
#  iters phi: 24
# 4,5:  solver time theta: 0.1225724975268046 mins
#  iters theta: 24
# 4,12:  solver time phi: 0.09051135381062826 mins
#  iters phi: 24
# 5,3:  solver time phi: 0.09249311685562134 mins
#  iters phi: 244,9:  solver time phi: 0.1015595277150472 mins
#  iters phi: 244,12:  solver time theta: 0.12334241867065429 mins
#  iters theta: 24
# 5,3:  solver time theta: 0.10530324379603068 mins
#  iters theta: 23
#
#
# 4,9:  solver time theta: 0.1254099408785502 mins
#  iters theta: 24
# 5,2:  solver time phi: 0.10379636685053507 mins
#  iters phi: 24
# 5,2:  solver time theta: 0.11061111291249594 mins
#  iters theta: 24
# 5,0:  solver time phi: 0.10017113288243612 mins
#  iters phi: 24
# 5,0:  solver time theta: 0.11880686283111572 mins
#  iters theta: 23
# 4,11:  solver time phi: 0.09793686866760254 mins
#  iters phi: 24
# 4,11:  solver time theta: 0.13652919133504232 mins
#  iters theta: 24
# 4,10:  solver time phi: 0.11029192606608072 mins
#  iters phi: 24
# 4,10:  solver time theta: 0.13059691190719605 mins
#  iters theta: 24
# 5,4:  solver time phi: 0.11156177918116252 mins
#  iters phi: 24
# 5,4:  solver time theta: 0.11519818703333537 mins
#  iters theta: 24
# 5,8:  solver time phi: 0.10035446087519327 mins
#  iters phi: 24
# 5,8:  solver time theta: 0.12342912753423055 mins
#  iters theta: 24
# 5,7:  solver time phi: 0.10119231541951497 mins
#  iters phi: 24
# 5,7:  solver time theta: 0.12733643849690754 mins
#  iters theta: 24
# 5,9:  solver time phi: 0.10441765785217286 mins
#  iters phi: 24
# 5,9:  solver time theta: 0.11505988041559854 mins
#  iters theta: 23
# 5,6:  solver time phi: 0.10407216946283976 mins
#  iters phi: 24
# 5,6:  solver time theta: 0.13044967651367187 mins
#  iters theta: 23
# 5 10
# 5 11
# 5,5:  solver time phi: 0.11896630525588989 mins
#  iters phi: 24
# 5,5:  solver time theta: 0.13193424940109252 mins
#  iters theta: 24
# GMRES solves
# GMRES solves
# 5 12
# 5 13
# 6 0
# 6 1
# 6 2
# GMRES solves
# 6 3
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 6 4
# 6 5
# 6 6
# GMRES solves
# 6 7
# 6 8
# 6 9
# 6 10
# 6 11
# GMRES solves
# 6 12
# GMRES solves
# 6 13
# GMRES solves
# 7 0
# 7 1
# GMRES solves
# GMRES solves
# 7 2
# GMRES solves
# 7 3
# 7 4
# GMRES solves
# 7 5
# GMRES solves
# 7 6
# 7 7
# 7 8
# GMRES solves
# GMRES solves
# GMRES solves
# 7 9
# 7 10
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 7 11
# 7 12
# 7 13
# 8 0
# 8 1
# 8 2
# 8 3
# GMRES solves
# GMRES solves
# GMRES solves
# 8 4
# GMRES solves
# GMRES solves
# GMRES solves
# 8 5
# 8 6
# GMRES solves
# 8 7
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 5,10:  solver time phi: 0.1596674640973409 mins
#  iters phi: 24
# 5,10:  solver time theta: 0.12341171900431315 mins
#  iters theta: 24
# 5,11:  solver time phi: 0.15711737473805745 mins
#  iters phi: 24
# 5,11:  solver time theta: 0.11823997497558594 mins
#  iters theta: 24
# 5,12:  solver time phi: 0.10333101352055868 mins
#  iters phi: 24
# 5,12:  solver time theta: 0.09019803206125895 mins
#  iters theta: 24
# 6,2:  solver time phi: 0.09723680019378662 mins
#  iters phi: 236,1:  solver time phi: 0.10750965277353923 mins
#  iters phi: 22
# 6,1:  solver time theta: 0.10250770250956218 mins
#  iters theta: 23
#
# 6,2:  solver time theta: 0.11460068225860595 mins
#  iters theta: 24
# 5,13:  solver time phi: 0.11247247854868571 mins
#  iters phi: 24
# 5,13:  solver time theta: 0.10849237442016602 mins
#  iters theta: 24
# 6,0:  solver time phi: 0.10825680096944174 mins
#  iters phi: 23
# 6,0:  solver time theta: 0.10382424592971802 mins
#  iters theta: 23
# 6,3:  solver time phi: 0.11008399724960327 mins
#  iters phi: 23
# 6,3:  solver time theta: 0.09939466714859009 mins
#  iters theta: 24
# 6,4:  solver time phi: 0.08954677184422812 mins
#  iters phi: 24
# 6,4:  solver time theta: 0.10267897446950276 mins
#  iters theta: 24
# 6,10:  solver time phi: 0.10186299880345663 mins
#  iters phi: 24
# 6,10:  solver time theta: 0.0882308840751648 mins
#  iters theta: 24
# 6,7:  solver time phi: 0.10713011026382446 mins
#  iters phi: 24
# 6,7:  solver time theta: 0.09019676844278972 mins
#  iters theta: 24
# 6,9:  solver time phi: 0.11006296475728353 mins
#  iters phi: 24
# 6,9:  solver time theta: 0.0894568125406901 mins
#  iters theta: 24
# 6,5:  solver time phi: 0.11802968978881836 mins
#  iters phi: 24
# 6,5:  solver time theta: 0.1029645601908366 mins
#  iters theta: 24
# 7,0:  solver time phi: 0.11306242148081462 mins
#  iters phi: 237,7:  solver time phi: 0.08902033964792887 mins
#  iters phi: 24
#
# 7,0:  solver time theta: 0.0880117932955424 mins
#  iters theta: 247,7:  solver time theta: 0.0942789594332377 mins
#  iters theta: 24
#
# 6,13:  solver time phi: 0.10126643975575765 mins
#  iters phi: 24
# 6,13:  solver time theta: 0.10851892232894897 mins
#  iters theta: 24
# 6,8:  solver time phi: 0.11643367211023967 mins
#  iters phi: 247,3:  solver time phi: 0.10001885890960693 mins
#  iters phi: 23
#
# 6,8:  solver time theta: 0.11252765655517578 mins
#  iters theta: 24
# 7,3:  solver time theta: 0.10299864212671915 mins
#  iters theta: 24
# 6,11:  solver time phi: 0.12123058636983236 mins
#  iters phi: 24
# 6,11:  solver time theta: 0.11092906792958578 mins
#  iters theta: 24
# 6,6:  solver time phi: 0.13178586959838867 mins
#  iters phi: 23
# 6,6:  solver time theta: 0.11729786396026612 mins
#  iters theta: 25
# 7,5:  solver time phi: 0.09869222243626913 mins
#  iters phi: 24
# 7,5:  solver time theta: 0.10849781036376953 mins
#  iters theta: 24
# 7,10:  solver time phi: 0.10457104444503784 mins
#  iters phi: 24
# 7,10:  solver time theta: 0.10082687139511108 mins
#  iters theta: 247,1:  solver time phi: 0.11333820422490438 mins
#  iters phi: 237,6:  solver time phi: 0.11315797964731852 mins
#  iters phi: 24
# 7,2:  solver time phi: 0.11013575792312622 mins
#  iters phi: 24
#
# 7,1:  solver time theta: 0.11331649621327718 mins
#  iters theta: 24
#
# 7,2:  solver time theta: 0.11653898557027181 mins
#  iters theta: 247,6:  solver time theta: 0.1097606062889099 mins
#  iters theta: 24
#
# 6,12:  solver time phi: 0.11694903373718261 mins
#  iters phi: 24
# 6,12:  solver time theta: 0.1244581699371338 mins
#  iters theta: 247,8:  solver time phi: 0.1064398209253947 mins
#  iters phi: 24
#
# 7,8:  solver time theta: 0.12229100465774537 mins
#  iters theta: 24
# 7,9:  solver time phi: 0.11446656386057535 mins
#  iters phi: 23
# 7,9:  solver time theta: 0.1098973552385966 mins
#  iters theta: 24
# 7,12:  solver time phi: 0.09838125705718995 mins
#  iters phi: 24
# 7,12:  solver time theta: 0.09730006456375122 mins
#  iters theta: 24
# 7,4:  solver time phi: 0.12204393545786539 mins
#  iters phi: 25
# 7,4:  solver time theta: 0.1278284231821696 mins
#  iters theta: 24
# 7,13:  solver time phi: 0.1002989649772644 mins
#  iters phi: 24
# 7,13:  solver time theta: 0.10564783414204916 mins
#  iters theta: 24
# 8,3:  solver time phi: 0.0974198818206787 mins
#  iters phi: 24
# 8,3:  solver time theta: 0.0976512591044108 mins
#  iters theta: 23
# 8,2:  solver time phi: 0.09937487045923869 mins
#  iters phi: 24
# 8,2:  solver time theta: 0.10211845636367797 mins
#  iters theta: 23
# 8,1:  solver time phi: 0.09741484721501668 mins
#  iters phi: 238,0:  solver time phi: 0.088104248046875 mins
#  iters phi: 23
#
# 8,0:  solver time theta: 0.11403098503748575 mins
#  iters theta: 238,1:  solver time theta: 0.09862621227900187 mins
#  iters theta: 23
#
# 7,11:  solver time phi: 0.10837146838506063 mins
#  iters phi: 23
# 7,11:  solver time theta: 0.14112993081410727 mins
#  iters theta: 24
# 8,7:  solver time phi: 0.09598460992177328 mins
#  iters phi: 24
# 8,7:  solver time theta: 0.10994470119476318 mins
#  iters theta: 23
# 8,4:  solver time phi: 0.11770356893539428 mins
#  iters phi: 24
# 8,4:  solver time theta: 0.11987830797831217 mins
#  iters theta: 24
# 8,6:  solver time phi: 0.10450286467870076 mins
#  iters phi: 25
# 8,6:  solver time theta: 0.1265268286069234 mins
#  iters theta: 23
# 8 8
# 8,5:  solver time phi: 0.1128115177154541 mins
#  iters phi: 24
# 8,5:  solver time theta: 0.12724227110544842 mins
#  iters theta: 24
# 8 9
# GMRES solves
# 8 10
# 8 11
# 8 12
# GMRES solves
# GMRES solves
# 8 13
# 9 0
# GMRES solves
# 9 1
# 9 2
# GMRES solves
# 9 3
# GMRES solves
# 9 4
# GMRES solves
# GMRES solves
# 9 5
# 9 6
# GMRES solves
# 9 7
# 9 8
# 9 9
# GMRES solves
# 9 10
# GMRES solves
# 9 11
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 9 12
# GMRES solves
# 9 13
# GMRES solves
# GMRES solves
# GMRES solves
# GMRES solves
# 8,8:  solver time phi: 0.0849166472752889 mins
#  iters phi: 24
# 8,8:  solver time theta: 0.10431934197743734 mins
#  iters theta: 23
# 8,11:  solver time phi: 0.1069662054379781 mins
#  iters phi: 24
# 9,1:  solver time phi: 0.09858732223510742 mins
#  iters phi: 238,11:  solver time theta: 0.08853522141774496 mins
#  iters theta: 24
#
# 9,1:  solver time theta: 0.07346463600794474 mins
#  iters theta: 228,9:  solver time phi: 0.11097914775212606 mins
#  iters phi: 24
#
# 8,10:  solver time phi: 0.10900437831878662 mins
#  iters phi: 248,9:  solver time theta: 0.10138945976893107 mins
#  iters theta: 24
#
# 8,10:  solver time theta: 0.1007583737373352 mins
#  iters theta: 24
# 9,0:  solver time phi: 0.10775232315063477 mins
#  iters phi: 23
# 9,0:  solver time theta: 0.07648179133733114 mins
#  iters theta: 23
# 9,6:  solver time phi: 0.08498538335164388 mins
#  iters phi: 25
# 9,6:  solver time theta: 0.08719361623128255 mins
#  iters theta: 23
# 9,7:  solver time phi: 0.08961062033971151 mins
#  iters phi: 25
# 9,7:  solver time theta: 0.08183680772781372 mins
#  iters theta: 23
# 9,11:  solver time phi: 0.09078300793965657 mins
#  iters phi: 249,8:  solver time phi: 0.09908361832300822 mins
#  iters phi: 24
#
# 9,11:  solver time theta: 0.06659411191940308 mins
#  iters theta: 249,8:  solver time theta: 0.07974057197570801 mins
#  iters theta: 24
#
# 9,3:  solver time phi: 0.11258451143900554 mins
#  iters phi: 23
# 8,12:  solver time phi: 0.12192640701929729 mins
#  iters phi: 249,3:  solver time theta: 0.0748567263285319 mins
#  iters theta: 23
#
# 8,12:  solver time theta: 0.10158028999964396 mins
#  iters theta: 24
# 8,13:  solver time phi: 0.12299195130666098 mins
#  iters phi: 24
# 8,13:  solver time theta: 0.09137469530105591 mins
#  iters theta: 24
# 9,2:  solver time phi: 0.1346964955329895 mins
#  iters phi: 23
# 9,2:  solver time theta: 0.07666858037312825 mins
#  iters theta: 23
# 9,5:  solver time phi: 0.1096006711324056 mins
#  iters phi: 24
# 9,5:  solver time theta: 0.07879660924275717 mins
#  iters theta: 23
# 9,4:  solver time phi: 0.11680047114690145 mins
#  iters phi: 24
# 9,4:  solver time theta: 0.08503477176030477 mins
#  iters theta: 23
# 9,10:  solver time phi: 0.10909520785013835 mins
#  iters phi: 249,12:  solver time phi: 0.08818881909052531 mins
#  iters phi: 24
#
# 9,10:  solver time theta: 0.0833124319712321 mins
#  iters theta: 249,12:  solver time theta: 0.08892073233922322 mins
#  iters theta: 24
#
# 9,9:  solver time phi: 0.12287861108779907 mins
#  iters phi: 24
# 9,9:  solver time theta: 0.08944975932439168 mins
#  iters theta: 24
# 9,13:  solver time phi: 0.1211683988571167 mins
#  iters phi: 25
# 9,13:  solver time theta: 0.11846015850702922 mins
#  iters theta: 24
# Total time: 1.8577813108762105 mins
# -------------------------------------------------------------------

# %%
weights_averaging = []
theta_inc = []
phi_inc = []
iterations_theta = []
iterations_phi = []
solver_time_phi = []
solver_time_theta = []
Cext = []
Csca = []
Cbsca = []
g = []
w = []
Z11 = []
Z12 = []
Z13 = []
Z14 = []
Z21 = []
Z22 = []
Z23 = []
Z24 = []
Z31 = []
Z32 = []
Z33 = []
Z34 = []
Z41 = []
Z42 = []
Z43 = []
Z44 = []

a.sort(key=lambda element: (element[0], element[1]) )

weights_averaging.append([r[2] for r in a])
theta_inc.append([r[3] for r in a])
phi_inc.append([r[4] for r in a])
iterations_theta.append([r[6] for r in a])
iterations_phi.append([r[5] for r in a])
solver_time_phi.append([r[7] for r in a])
solver_time_theta.append([r[8] for r in a])
Cext.append([r[9] for r in a])
Csca.append([r[10] for r in a])
w.append([r[11] for r in a])
g.append([r[12] for r in a])
Cbsca.append([r[13] for r in a])
Z11.append([r[14] for r in a])
Z12.append([r[15] for r in a])
Z13.append([r[16] for r in a])
Z14.append([r[17] for r in a])
Z21.append([r[18] for r in a])
Z22.append([r[19] for r in a])
Z23.append([r[20] for r in a])
Z24.append([r[21] for r in a])
Z31.append([r[22] for r in a])
Z32.append([r[23] for r in a])
Z33.append([r[24] for r in a])
Z34.append([r[25] for r in a])
Z41.append([r[26] for r in a])
Z42.append([r[27] for r in a])
Z43.append([r[28] for r in a])
Z44.append([r[29] for r in a])

# %%
Cext = np.reshape(np.array(Cext[0]), (N_gauss, n_waves))
Csca = np.reshape(np.array(Csca[0]), (N_gauss, n_waves))
Cbsca = np.reshape(np.array(Cbsca[0]), (N_gauss, n_waves))
g = np.reshape(np.array(g[0]), (N_gauss, n_waves))
w = np.reshape(np.array(w[0]), (N_gauss, n_waves))

Cext_avg = np.dot(weights_gamma,np.dot(Cext, w_averaging))
Csca_avg = np.dot(weights_gamma,np.dot(Csca, w_averaging))
Cbsca_avg = np.dot(weights_gamma,np.dot(Cbsca, w_averaging))
g_avg = np.dot(weights_gamma,np.dot(g, w_averaging))
w_avg = np.dot(weights_gamma,np.dot(w, w_averaging))

print("Error in Csca: {0:.5%}".format(abs(Csca_avg - Csca_Tmatrix)/Csca_Tmatrix))
print("Error in Cext: {0:.5%}".format(abs(Cext_avg - Cext_Tmatrix)/Cext_Tmatrix))
print("Error in Cbsca: {0:.5%}".format(abs(Cbsca_avg - Cbsca_Tmatrix)/Cbsca_Tmatrix))
print("Error in g: {0:.5%}".format(abs(g_avg - g_Tmatrix)/g_Tmatrix))
print("Error in w: {0:.5%}".format(abs(w_avg - w_Tmatrix)/w_Tmatrix))
# Out:
# Error in Csca: 0.18164%
# Error in Cext: 0.14759%
# Error in Cbsca: 0.52520%
# Error in g: 0.77069%
# Error in w: 0.05354%

# %%
Z11 = np.transpose(np.reshape(np.array(Z11[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z12 = np.transpose(np.reshape(np.array(Z12[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z13 = np.transpose(np.reshape(np.array(Z13[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z14 = np.transpose(np.reshape(np.array(Z14[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z21 = np.transpose(np.reshape(np.array(Z21[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z22 = np.transpose(np.reshape(np.array(Z22[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z23 = np.transpose(np.reshape(np.array(Z23[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z24 = np.transpose(np.reshape(np.array(Z24[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z31 = np.transpose(np.reshape(np.array(Z31[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z32 = np.transpose(np.reshape(np.array(Z32[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z33 = np.transpose(np.reshape(np.array(Z33[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z34 = np.transpose(np.reshape(np.array(Z34[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z41 = np.transpose(np.reshape(np.array(Z41[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z42 = np.transpose(np.reshape(np.array(Z42[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z43 = np.transpose(np.reshape(np.array(Z43[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))
Z44 = np.transpose(np.reshape(np.array(Z44[0]), (N_gauss, n_waves, number_of_angles)), axes = (0,2,1))

# %%
Z11_avg = np.dot(weights_gamma, np.dot(Z11, w_averaging))
Z12_avg = np.dot(weights_gamma, np.dot(Z12, w_averaging))
Z13_avg = np.dot(weights_gamma, np.dot(Z13, w_averaging))
Z14_avg = np.dot(weights_gamma, np.dot(Z14, w_averaging))
Z21_avg = np.dot(weights_gamma, np.dot(Z21, w_averaging))
Z22_avg = np.dot(weights_gamma, np.dot(Z22, w_averaging))
Z23_avg = np.dot(weights_gamma, np.dot(Z23, w_averaging))
Z24_avg = np.dot(weights_gamma, np.dot(Z24, w_averaging))
Z31_avg = np.dot(weights_gamma, np.dot(Z31, w_averaging))
Z32_avg = np.dot(weights_gamma, np.dot(Z32, w_averaging))
Z33_avg = np.dot(weights_gamma, np.dot(Z33, w_averaging))
Z34_avg = np.dot(weights_gamma, np.dot(Z34, w_averaging))
Z41_avg = np.dot(weights_gamma, np.dot(Z41, w_averaging))
Z42_avg = np.dot(weights_gamma, np.dot(Z42, w_averaging))
Z43_avg = np.dot(weights_gamma, np.dot(Z43, w_averaging))
Z44_avg = np.dot(weights_gamma, np.dot(Z44, w_averaging))

# %%
Z11_g = np.dot(np.sin(np.linspace(0, np.pi, number_of_angles))*np.cos(np.linspace(0, np.pi, number_of_angles)), Z11_avg)*np.pi**2*2/(number_of_angles*Csca_avg)

print("Error in g: {0:.5%}".format(abs(Z11_g - g_Tmatrix)/g_Tmatrix))
# Out:
# Error in g: 0.23811%

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
scaling = 4*np.pi/Csca_avg
number_of_angles = np.shape(Z11)[1]
angles_theta = np.linspace(0,np.pi,number_of_angles)

fig, axs = plt.subplots(2, 3, figsize = (18,12))

axs[0, 0].semilogy(Tmatrix_coords, Z11_Tmatrix, 'navy', linewidth=3, label = 'T-matrix')
axs[0, 0].semilogy(angles_theta, scaling*Z11_avg, '--',color ='lightcoral', linewidth=3, label = 'BEM')
axs[0, 0].set_title(r'$\langle Z_{11} \rangle$', fontsize = 20)
axs[0, 0].legend(fontsize = 16)
axs[0, 0].set_xlabel('scattering angle', fontsize = 20)
axs[0, 0].tick_params(axis = 'both', labelsize = 20)
# axs[0, 0].set_ylim([7E-1, 1.6])
# axs[0, 0].set_yticklabels([7E-1, 1])

axs[0, 1].plot(Tmatrix_coords, Z12_Tmatrix, 'navy', linewidth=3, label = 'T-matrix')
axs[0, 1].plot(angles_theta, scaling*Z12_avg, '--',color ='lightcoral', linewidth=3, label = 'BEM')
axs[0, 1].set_title(r'$\langle Z_{12} \rangle$', fontsize = 20)
axs[0, 1].set_xlabel('scattering angle', fontsize = 20)
axs[0, 1].tick_params(axis = 'both', labelsize = 20)

axs[0, 2].plot(Tmatrix_coords, Z34_Tmatrix, 'navy', linewidth=3, label = 'T-matrix')
axs[0, 2].plot(angles_theta,scaling* Z34_avg, '--',color ='lightcoral', linewidth=3, label = 'BEM')
axs[0, 2].set_title(r'$\langle Z_{34} \rangle$', fontsize = 20)
# axs[0, 2].set_ylim([-0.1, 0.1])
axs[0, 2].set_xlabel('scattering angle', fontsize = 20)
axs[0, 2].tick_params(axis = 'both', labelsize = 20)

axs[1, 0].plot(Tmatrix_coords, Z22_Tmatrix, 'navy', linewidth=3, label = 'T-matrix')
axs[1, 0].plot(angles_theta, scaling*Z22_avg, '--',color ='lightcoral', linewidth=3, label = 'BEM')
axs[1, 0].set_title(r'$\langle Z_{22} \rangle$', fontsize = 20)
axs[1, 0].set_xlabel('scattering angle', fontsize = 20)
axs[1, 0].tick_params(axis = 'both', labelsize = 20)

axs[1, 1].plot(Tmatrix_coords, Z33_Tmatrix, 'navy', linewidth=3, label = 'T-matrix')
axs[1, 1].plot(angles_theta, scaling*Z33_avg, '--',color ='lightcoral', linewidth=3, label = 'BEM')
axs[1, 1].set_title(r'$\langle Z_{33} \rangle$', fontsize = 20)
axs[1, 1].set_xlabel('scattering angle', fontsize = 20)
axs[1, 1].tick_params(axis = 'both', labelsize = 20)

axs[1, 2].plot(Tmatrix_coords, Z44_Tmatrix, 'navy', linewidth=3, label = 'T-matrix')
axs[1, 2].plot(angles_theta,scaling* Z44_avg, '--',color ='lightcoral', linewidth=3, label = 'BEM')
axs[1, 2].set_title(r'$\langle Z_{44} \rangle$', fontsize = 20)
axs[1, 2].set_xlabel('scattering angle', fontsize = 20)
axs[1, 2].tick_params(axis = 'both', labelsize = 20)

plt.suptitle(r'$X=1$', fontsize = 24)
plt.tight_layout(rect=[0, 0.03, 1, 0.9])
